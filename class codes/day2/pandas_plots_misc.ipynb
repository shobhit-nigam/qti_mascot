# %%
50 + 7
# Out:
# 57

# %%
import pandas as pd

# %%
data = {
    'hero': ["Naruto", "Sasuke", "Sakura", "Kakashi"],
    'power level': [9000, 8500, 7000, 9500],
    'Village': ["Leaf", "Leaf", "Leaf", "Leaf"]
}

# %%
df_a = pd.DataFrame(data)

# %%
df_a
# Out:
#       hero  power level Village
# 0   Naruto         9000    Leaf
# 1   Sasuke         8500    Leaf
# 2   Sakura         7000    Leaf
# 3  Kakashi         9500    Leaf

# %%
df_a['hero']
# Out:
# 0     Naruto
# 1     Sasuke
# 2     Sakura
# 3    Kakashi
# Name: hero, dtype: object

# %%
df_a.iloc[2]
# Out:
# hero           Sakura
# power level      7000
# Village          Leaf
# Name: 2, dtype: object

# %%
# filtering condition
df_a['power level'] >= 9000

# %%
df_a[ df_a['power level'] >= 9000 ]
# Out:
#       hero  power level Village
# 0   Naruto         9000    Leaf
# 3  Kakashi         9500    Leaf

# %%
# data cleaning
df_a['power level'] = df_a['power level'].replace(9000, 9500)

# %%
df_a
# Out:
#       hero  power level Village
# 0   Naruto         9500    Leaf
# 1   Sasuke         8500    Leaf
# 2   Sakura         7000    Leaf
# 3  Kakashi         9500    Leaf

# %%
df_a['Age'] = pd.Series( [17, 18, 16, 27] )

# %%
df_a
# Out:
#       hero  power level Village  Age
# 0   Naruto         9500    Leaf   17
# 1   Sasuke         8500    Leaf   18
# 2   Sakura         7000    Leaf   16
# 3  Kakashi         9500    Leaf   27

# %%
df_a['rank'] = pd.Series([ 'A', 'B', 'A'] )

# %%
df_a
# Out:
#       hero  power level Village  Age rank
# 0   Naruto         9500    Leaf   17    A
# 1   Sasuke         8500    Leaf   18    B
# 2   Sakura         7000    Leaf   16    A
# 3  Kakashi         9500    Leaf   27  NaN

# %%
df_a.at[3, 'rank'] = 'C'

# %%
df_a
# Out:
#       hero  power level Village  Age rank
# 0   Naruto         9500    Leaf   17    A
# 1   Sasuke         8500    Leaf   18    B
# 2   Sakura         7000    Leaf   16    A
# 3  Kakashi         9500    Leaf   27    C

# %%
# aggregate 
# rank  pl     age
#  A    16500  33
#  B    8500   18

# %%
df_a.groupby('rank').agg( {
    'power level' : 'sum', 
    'Age' : 'mean'
} )
# Out:
#       power level   Age
# rank
# A           16500  16.5
# B            8500  18.0
# C            9500  27.0

# %%
df_a.groupby('rank').mean()
# Out:
#       power level   Age
# rank
# A          8250.0  16.5
# B          8500.0  18.0
# C          9500.0  27.0

# %%
# ipynb (iPython note book)

# %%
new_data = {
    'hero': ['Shikamaru', 'Hinata'],
    'power level': [8000, 6500],
    'Village': ["Leaf", "Leaf"], 
    'Age' : [19, 16], 
    'rank' : ['B', 'A']
}

df_b = pd.DataFrame(new_data)

# %%
df_c = pd.concat([df_a, df_b], ignore_index=True)

df_c
# Out:
#         hero  power level Village  Age rank
# 0     Naruto         9500    Leaf   17    A
# 1     Sasuke         8500    Leaf   18    B
# 2     Sakura         7000    Leaf   16    A
# 3    Kakashi         9500    Leaf   27    C
# 4  Shikamaru         8000    Leaf   19    B
# 5     Hinata         6500    Leaf   16    A

# %%
df_c.shape
# Out:
# (6, 5)

# %%
len(df_c)
# Out:
# 6

# %%
df_c.loc[6] = ['Parika', 8000, 'Leaf', 19, 'B']

# %%
df_c
# Out:
#         hero  power level Village  Age rank
# 0     Naruto         9500    Leaf   17    A
# 1     Sasuke         8500    Leaf   18    B
# 2     Sakura         7000    Leaf   16    A
# 3    Kakashi         9500    Leaf   27    C
# 4  Shikamaru         8000    Leaf   19    B
# 5     Hinata         6500    Leaf   16    A
# 6     Parika         8000    Leaf   19    B

# %% [markdown]
# normal text
#
# #### header

# %%
import matplotlib.pyplot as plt 
#from matplotlib import pyplot as plt

# %%
# bar plot of hero power levels
plt.bar(df_c['hero'], df_c['power level'])
# Out:
# <BarContainer object of 7 artists>

# %%
plt.bar(df_c['hero'], df_c['power level'])
plt.title("hero power levels")
plt.xlabel("hero")
plt.ylabel("power level")
plt.show()

# %%
plt.bar(df_c['hero'], df_c['power level'], color='orange')
plt.title("hero power levels")
plt.xlabel("hero")
plt.ylabel("power level")
plt.show()

# %%
plt.plot(df_c['hero'], df_c['power level'], color='orange')
plt.title("hero power levels")
plt.xlabel("hero")
plt.ylabel("power level")
plt.show()

# %%
plt.plot(df_c['hero'], df_c['power level'], color='green', marker = 'o', linestyle = '--')
plt.title("hero power levels")
plt.xlabel("hero")
plt.ylabel("power level")
plt.show()

# %%
help(plt)
# Out:
# Help on module matplotlib.pyplot in matplotlib:
#
# NAME
#     matplotlib.pyplot
#
# DESCRIPTION
#     `matplotlib.pyplot` is a state-based interface to matplotlib. It provides
#     a MATLAB-like way of plotting.
#
#     pyplot is mainly intended for interactive plots and simple cases of
#     programmatic plot generation::
#
#         import numpy as np
#         import matplotlib.pyplot as plt
#
#         x = np.arange(0, 5, 0.1)
#         y = np.sin(x)
#         plt.plot(x, y)
#
#     The object-oriented API is recommended for more complex plots.
#
# FUNCTIONS
#     acorr(x, *, data=None, **kwargs)
#         Plot the autocorrelation of *x*.
#
#         Parameters
#         ----------
#         x : array-like
#
#         detrend : callable, default: `.mlab.detrend_none` (no detrending)
#             A detrending function applied to *x*.  It must have the
#             signature ::
#
#                 detrend(x: np.ndarray) -> np.ndarray
#
#         normed : bool, default: True
# ...

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
plt.plot(df_c['hero'], df_c['power level'], color='green', marker = 'D', linestyle = '--')
plt.title("hero power levels")
plt.xlabel("hero")
plt.ylabel("power level")
plt.show()

# %%
plt.scatter(df_c['Age'], df_c['power level'], color='green')
plt.title("age vs power level")
plt.xlabel("age")
plt.ylabel("power level")
plt.savefig("age_vs_power_level.png")
plt.show()

# %%
# PEP 8 
#firstBluePrint() 

#first_blue_print()

# %%
def calculate_trength (ca, cb=0):
    "calculate average strength, please pass two varaibles"
    cx = ca + 2*cb
    # some code

# %%
help(calculate_trength)
# Out:
# Help on function calculate_trength in module __main__:
#
# calculate_trength(ca, cb=0)
#     calculate average strength, please pass two varaibles

# %%
# doc string

def calculate_trength (ca, cb=0):
    """calculate average strength, 
    please pass two varaibles
    default for ca is zero"""
    cx = ca + 2*cb
    # some code

# %%
help(calculate_trength)
# Out:
# Help on function calculate_trength in module __main__:
#
# calculate_trength(ca, cb=0)
#     calculate average strength,
#     please pass two varaibles
#     default for ca is zero

# %%
import sys
sys.version
# Out:
# '3.7.7 (default, Mar 26 2020, 10:32:53) \n[Clang 4.0.1 (tags/RELEASE_401/final)]'
